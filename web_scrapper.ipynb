# %%
import selenium
from selenium import webdriver
import pandas as pd
from selenium.webdriver.common.keys import Keys

# %%
pd.set_option('display.max_columns', None)

# %%
columns = ['player_name','unique_id','age','overall_score','height','weight',
                          'preferred_foot','best_position','player_value','weekly_wage','crossing',
                          'finishing','heading_accuracy','short_passing','volley','dribbling','curves',
                          'free_kick_accuracy','long_pass','ball_control','acceleration','sprint_speed',
                          'agility','reaction','balance','shot_power','jumping','stamina','strength','long_shot',
                          'aggression','interception','positioning','vision','penalties',
                          'composure','marking','standing_tackle','sliding_tackle','weak_foot','skill_moves',
                          'attacking_work_rate','defensive_work_rate','pace','shooting','passing','dribble',
                          'defense','physical']
player_data = pd.DataFrame(columns = columns)




driver = webdriver.Chrome()

for page in range(0,19680, 60):
#for page in range(0,60, 60):
    url ='https://sofifa.com/?currency=USD&col=vl&sort=desc&showCol%5B%5D=pi&showCol%5B%5D=ae&showCol%5B%5D=hi&showCol%5B%5D=wi&showCol%5B%5D=pf&showCol%5B%5D=oa&showCol%5B%5D=pt&showCol%5B%5D=bo&showCol%5B%5D=bp&showCol%5B%5D=gu&showCol%5B%5D=jt&showCol%5B%5D=le&showCol%5B%5D=vl&showCol%5B%5D=wg&showCol%5B%5D=rc&showCol%5B%5D=ta&showCol%5B%5D=cr&showCol%5B%5D=fi&showCol%5B%5D=he&showCol%5B%5D=sh&showCol%5B%5D=vo&showCol%5B%5D=ts&showCol%5B%5D=dr&showCol%5B%5D=cu&showCol%5B%5D=fr&showCol%5B%5D=lo&showCol%5B%5D=bl&showCol%5B%5D=to&showCol%5B%5D=ac&showCol%5B%5D=sp&showCol%5B%5D=ag&showCol%5B%5D=re&showCol%5B%5D=ba&showCol%5B%5D=tp&showCol%5B%5D=so&showCol%5B%5D=ju&showCol%5B%5D=st&showCol%5B%5D=sr&showCol%5B%5D=ln&showCol%5B%5D=te&showCol%5B%5D=ar&showCol%5B%5D=in&showCol%5B%5D=po&showCol%5B%5D=vi&showCol%5B%5D=pe&showCol%5B%5D=cm&showCol%5B%5D=td&showCol%5B%5D=ma&showCol%5B%5D=sa&showCol%5B%5D=sl&showCol%5B%5D=tt&showCol%5B%5D=bs&showCol%5B%5D=wk&showCol%5B%5D=sk&showCol%5B%5D=aw&showCol%5B%5D=dw&showCol%5B%5D=ir&showCol%5B%5D=pac&showCol%5B%5D=sho&showCol%5B%5D=pas&showCol%5B%5D=dri&showCol%5B%5D=def&showCol%5B%5D=phy&offset='+ str(page)
    driver.get(url)
    
    #Player Name
    #player_name =[]
    pn = driver.find_elements_by_xpath('//td[@class ="col-name"]//a[@class="tooltip"]//div[@class ="bp3-text-overflow-ellipsis" ]')
    player_name = [pn[x].text for x in range(len(pn))]
    #player_name.append(pn)
    
    #age
    #age = []
    player_age = driver.find_elements_by_xpath('//td[@class = "col col-ae"]')
    age = [player_age[x].text for x in range(len(player_age))]
    #age.append(player_age)
    
    #overall score
    #overall_score =[]
    os = driver.find_elements_by_xpath('//td[@class = "col col-oa"]')
    overall_score = [os[x].text for x in range(len(os))]
    #overall_score.append(os)
    
    #unique ids
    #unique_id = []
    ids = driver.find_elements_by_xpath('//td[@class = "col col-pi"]')
    unique_id = [ids[x].text for x in range(len(ids))]
    #unique_id.append(ids)
    
    #height
    #height= []
    p_height = driver.find_elements_by_xpath('//td[@class = "col col-hi"]')
    height = [p_height[x].text for x in range(len(p_height))]
    #height.append(p_height)
    
    #weight
    #weight = []
    p_weight = driver.find_elements_by_xpath('//td[@class = "col col-wi"]')
    weight = [p_weight[x].text for x in range(len(p_weight))]
    #weight.append(p_weight)
    
    #preferred foot
    #preferred_foot =[]
    pref_foot = driver.find_elements_by_xpath('//td[@class = "col col-pf"]')
    preferred_foot = [pref_foot[x].text for x in range(len(pref_foot))]
    #preferred_foot.append(pref_foot)
    
    #best position
    #best_position = []
    best_pos = driver.find_elements_by_xpath('//td[@class = "col col-bp"]')
    best_position = [best_pos[x].text for x in range(len(best_pos))]
    #best_position.append(best_pos)
    
    #player value
    #player_value = []
    value = driver.find_elements_by_xpath('//td[@data-col = "vl"]')
    player_value = [value[x].text for x in range(len(value))]
    #player_value.append(value)
    
    #weekly wage
    #weekly_wage =[]
    wage = driver.find_elements_by_xpath('//td[@data-col="wg"]')
    weekly_wage = [wage[x].text for x in range(len(wage))]
    
    #crossing 
    #crossing =[]
    crossing_score = driver.find_elements_by_xpath('//td[@data-col="cr"]')
    crossing = [crossing_score[x].text for x in range(len(crossing_score))]
    #crossing.append(crossing_score)
    
    #finishing
    #finishing=[]
    finishing_score = driver.find_elements_by_xpath('//td[@data-col="fi"]')
    finishing = [finishing_score[x].text for x in range(len(finishing_score))]
    #finishing.append(finishing_score)
    
    #heading accuracy 
    #heading_accuracy = []
    heading_ac = driver.find_elements_by_xpath('//td[@data-col = "he"]')
    heading_accuracy = [heading_ac[x].text for x in range(len(heading_ac))]
    #heading_accuracy.append(heading_ac)
    
    #short passing
    #short_passing = []
    short_pass = driver.find_elements_by_xpath('//td[@data-col="sh"]')
    short_passing = [short_pass[x].text for x in range(len(short_pass))]
    #short_passing.append(short_pass)
    
    #volley 
    #volley = []
    volleys = driver.find_elements_by_xpath('//td[@data-col="vo"]')
    volley = [volleys[x].text for x in range(len(volleys))]
    #volley.append(volleys)
    
    #dribbling
    #dribbling = []
    dribbling_score = driver.find_elements_by_xpath('//td[@data-col="dr"]')
    dribbling = [dribbling_score[x].text for x in range(len(dribbling_score))]
    #dribbling.append(dribbling_score)
    
    #curves
    #curves = []
    curve = driver.find_elements_by_xpath('//td[@data-col="cu"]')
    curves = [curve[x].text for x in range(len(curve))]
    #curves.append(curve)
    
    #free kick accuracy
    #free_kick_accuracy = []
    free_kick = driver.find_elements_by_xpath('//td[@data-col="fr"]')
    free_kick_accuracy = [free_kick[x].text for x in range(len(free_kick))]
    #free_kick_accuracy.append(free_kick)
    
    #long pass
    #long_pass = []
    long = driver.find_elements_by_xpath('//td[@data-col = "lo"]')
    long_pass = [long[x].text for x in range(len(long))]
    #long_pass.append(long)
    
    #ball control
    #ball_control = []
    ball_con = driver.find_elements_by_xpath('//td[@data-col="bl"]')
    ball_control = [ball_con[x].text for x in range(len(ball_con))]
    #ball_control.append(ball_con)
    
    #acceleration
    #acceleration = []
    accel = driver.find_elements_by_xpath('//td[@data-col="ac"]')
    acceleration = [accel[x].text for x in range(len(accel))]
    #acceleration.append(accel)
    
    #sprint speed
    #sprint_speed = []
    sprint_sp = driver.find_elements_by_xpath('//td[@data-col="sp"]')
    sprint_speed = [sprint_sp[x].text for x in range(len(sprint_sp))]
    #sprint_speed.append(sprint_sp)
    
    #agiligy
    #agility =[]
    agi_sc = driver.find_elements_by_xpath('//td[@data-col="ag"]')
    agility = [agi_sc[x].text for x in range(len(agi_sc))]
    #agility.append(agi_sc)
    
    #reaction
    #reaction = []
    reac_sc = driver.find_elements_by_xpath('//td[@data-col="re"]')
    reaction = [reac_sc[x].text for x in range(len(reac_sc))]
    #reaction.append(reac_sc)
    
    #balance 
    #balance = []
    bal = driver.find_elements_by_xpath('//td[@data-col="ba"]')
    balance = [bal[x].text for x in range(len(bal))]
    #balance.append(bal)
    
    #shot power
    #shot_power = []
    shot_po = driver.find_elements_by_xpath('//td[@data-col="so"]')
    shot_power = [shot_po[x].text for x in range(len(shot_po))]
    #shot_power.append(shot_po)
    
    #jumping
    #jumping = []
    jump = driver.find_elements_by_xpath('//td[@data-col="ju"]')
    jumping = [jump[x].text for x in range(len(jump))]
    #jumping.append(jump)
    
    #stamina
    #stamina =[]
    sta = driver.find_elements_by_xpath('//td[@data-col="st"]')
    stamina = [sta[x].text for x in range(len(sta))]
    #stamina.append(sta)
    
    #strength
    #strength =[]
    strength_sc = driver.find_elements_by_xpath('//td[@data-col="sr"]')
    strength = [strength_sc[x].text for x in range(len(strength_sc))]
    #strength.append(strength_sc)
    
    #long shot
    #long_shot =[]
    long_shots = driver.find_elements_by_xpath('//td[@data-col="ln"]')
    long_shot = [long_shots[x].text for x in range(len(long_shots))]
    #long_shot.append(long_shots)
    
    #aggression 
    #aggression = []
    aggression_score = driver.find_elements_by_xpath('//td[@data-col="ar"]')
    aggression = [aggression_score[x].text for x in range(len(aggression_score))]
    #aggression.append(aggression_score)
    
    #interception
    #interception = []    
    inter = driver.find_elements_by_xpath('//td[@data-col="in"]')
    interception = [inter[x].text for x in range(len(inter))]
    #interception.append(inter)
    
    #positioning
    #positioning = []
    posit = driver.find_elements_by_xpath('//td[@data-col="po"]')
    positioning = [posit[x].text for x in range(len(posit))]
    #positioning.append(posit)
    
    #vision
    #vision = []
    visi = driver.find_elements_by_xpath('//td[@data-col="vi"]')
    vision = [visi[x].text for x in range(len(visi))]
    #vision.append(visi)
    
    #penalties
    #penalties = []
    penal = driver.find_elements_by_xpath('//td[@data-col="pe"]')
    penalties = [penal[x].text for x in range(len(penal))]
    #penalties.append(penal)
    
    #composure 
    #composure = []
    comp = driver.find_elements_by_xpath('//td[@data-col="cm"]')
    composure = [comp[x].text for x in range(len(comp))]
    #composure.append(comp)
    
    #marking
    #marking = []
    mark = driver.find_elements_by_xpath('//td[@data-col="ma"]')
    marking = [mark[x].text for x in range(len(mark))]
    #marking.append(mark)
    
    #standing tackle
    #standing_tackle = []
    standing = driver.find_elements_by_xpath('//td[@data-col="sa"]')
    standing_tackle = [standing[x].text for x in range(len(standing))]
    #standing_tackle.append(standing)
    
    #sliding tackle
    #sliding_tackle = []
    sliding = driver.find_elements_by_xpath('//td[@data-col="sl"]')
    sliding_tackle = [sliding[x].text for x in range(len(sliding))]
    #sliding_tackle.append(sliding)
    
    #weak foot
    #weak_foot = []
    weak = driver.find_elements_by_xpath('//td[@data-col="wk"]')
    weak_foot = [weak[x].text for x in range(len(weak))]
    #weak_foot.append(weak)
    
    #skill moves
    #skill_moves = []
    skill_m = driver.find_elements_by_xpath('//td[@data-col="sk"]')
    skill_moves= [skill_m[x].text for x in range(len(skill_m))]
    #skill_moves.append(skill_m)
    
    #attackig work rate
    #attacking_work_rate = []
    awr = driver.find_elements_by_xpath('//td[@data-col="aw"]')
    attacking_work_rate = [awr[x].text for x in range(len(awr))]
    #attacking_work_rate.append(awr)
    
    #defensive work rate
   # defensive_work_rate =[]
    dwr = driver.find_elements_by_xpath('//td[@data-col="dw"]')
    defensive_work_rate = [dwr[x].text for x in range(len(dwr))]
    #defensive_work_rate.append(dwr)
    
    #PACE
    #pace =[]
    PACE = driver.find_elements_by_xpath('//td[@data-col="pac"]')
    pace = [PACE[x].text for x in range(len(PACE))]
    #pace.append(PACE)
    
    #shooting
    #shooting = []    
    shoox = driver.find_elements_by_xpath('//td[@data-col="sho"]')
    shooting = [shoox[x].text for x in range(len(shoox))]
    #shooting.append(shoox)
    
    #passing
    #passing =[]
    pat = driver.find_elements_by_xpath('//td[@data-col="pas"]')
    passing = [pat[x].text for x in range(len(pat))]
    #passing.append(pat)
    
    #dribble
    #dribble = []
    drib = driver.find_elements_by_xpath('//td[@data-col="dri"]')
    dribble =[drib[x].text for x in range(len(drib))]
    #dribble.append(drib)
    
    #defense 
    #defense =[]
    deff = driver.find_elements_by_xpath('//td[@data-col="def"]')
    defense = [deff[x].text for x in range(len(deff))]
    #defense.append(deff)
    
    #phy
    #physical = []
    phy = driver.find_elements_by_xpath('//td[@data-col="phy"]')
    physical = [phy[x].text for x in range(len(phy))]
    #physical.append(phy)
    
 
    
    #data_tuples = list(zip(pn, player_age))
    
    data_tuples = list(zip(player_name,unique_id,age,overall_score,height,weight,
                          preferred_foot,best_position,player_value,weekly_wage,crossing,
                          finishing,heading_accuracy,short_passing,volley,dribbling,curves,
                          free_kick_accuracy,long_pass,ball_control,acceleration,sprint_speed,
                          agility,reaction,balance,shot_power,jumping,stamina,strength,long_shot,
                          aggression,interception,positioning,vision,penalties,
                          composure,marking,standing_tackle,sliding_tackle,weak_foot,skill_moves,
                          attacking_work_rate,defensive_work_rate,pace,shooting,passing,dribble,
                          defense,physical))
    #temp_df = pd.DataFrame(data_tuples,columns=columns)
    
    temp_df = pd.DataFrame(data_tuples, columns = ['player_name','unique_id','age','overall_score','height','weight',
                          'preferred_foot','best_position','player_value','weekly_wage','crossing',
                          'finishing','heading_accuracy','short_passing','volley','dribbling','curves',
                          'free_kick_accuracy','long_pass','ball_control','acceleration','sprint_speed',
                          'agility','reaction','balance','shot_power','jumping','stamina','strength','long_shot',
                          'aggression','interception','positioning','vision','penalties',
                          'composure','marking','standing_tackle','sliding_tackle','weak_foot','skill_moves',
                          'attacking_work_rate','defensive_work_rate','pace','shooting','passing','dribble',
                          'defense','physical'])
    
    player_data = player_data.append(temp_df,ignore_index=True)

# %%
#stop driver 
driver.quit()

# %%
#to csv
player_data.to_csv('player_data.csv',index=False)
